# %% [markdown]
# ## Домашнее задание "Центральная Предельная Теорема и Закон Больших Чисел".
# ### Задание.
# В этом задании нужно убедиться, что ЦПТ действительно работает.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
from scipy.stats import norm
# %matplotlib inline

# %% [markdown]
# ### Создать случайную величину из любого   распределения, для разных значений n сгенерировать 1000 выборок размера n и построить гистрограммы средних этих выборок.

# %%
rv = sts.expon()
sample = rv.rvs(size = 1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density = True, bins = 30, label = 'Sample histogram')
plt.plot(x, pdf, label = 'Theoretical pdf', alpha = 0.5)
plt.legend(loc = 'best', frameon = False)
plt.ylabel('Fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
n1 = 200
rv = sts.expon()
samples_count = 1000
a1 = np.array([])
for number in range(samples_count):
    sample1 = rv.rvs(size = n1)
    a1 = np.append(a1, sample1.mean())

# %%
label_1 = 'Sample of ' + str(n1) + ' histogram'
plt.hist(a1, density = True, label = label_1)
plt.legend(loc = 'best', frameon = False)
plt.ylabel('Samples means')
plt.xlabel('$x$')
plt.show()
