# %% [markdown]
# ## Домашнее задание "Математический анализ. Производная".
# #### Уровень 0:
# Посчитайте значение первой и второй производной функции:
#
# $f(x) = x^5 + 4sin(2x) + cos(3x+3)$
#
# В точке x = 1.
#
# #### Уровень 1:
# Постройте график первой и второй производной функции:
#
# $f(x) = sin^5(2x+1)$
#
# На отрезке [-5; 5].

# %% [markdown]
# ## Уровень 0:
# Посчитайте значение первой и второй производной функции:
#
# 𝑓(𝑥)=𝑥5+4𝑠𝑖𝑛(2𝑥)+𝑐𝑜𝑠(3𝑥+3)
# В точке x = 1.

# %%
import numpy as np
from sympy import *
from scipy.misc import derivative

# %%
x, y = symbols('x y') 
gfg_ex = x**5 + 4*sin(2*x) + cos(3*x+ 3)

# %%
# нахожу первую производную(для визуализации)
dif = diff(gfg_ex, x) 
dif
# Out:
# 5*x**4 - 3*sin(3*x + 3) + 8*cos(2*x)

# %%
# нахожу первую производную в точке x = 1
def f(x):
    return x**5 + 4*sin(2*x) + cos(3*x + 3)
derivative(f, 1.0, dx = 1e-6, n = 1)
# Out:
# 2.50907180188165

# %%
# нахожу вторую производную(для визуализации)
dif2 = diff(dif, x) 
dif2
# Out:
# 20*x**3 - 16*sin(2*x) - 9*cos(3*x + 3)

# %%
# нахожу вторую производную в точке x = 1
def f(x):
    return x**5 + 4*sin(2*x) + cos(3*x + 3)
derivative(f, 1.0, dx = 1e-6, n = 2)
# Out:
# -3.19033688356285

# %% [markdown]
# ## Уровень 1:
# Постройте график первой и второй производной функции:
# 𝑓(𝑥)=𝑠𝑖𝑛5(2𝑥+1)
# На отрезке [-5; 5]

# %%
import matplotlib.pyplot as plt

# %%
def f(x):
    return np.sin(2*x + 1)**5

# %%
x = np.linspace(-5, 5)
fx = f(x)
f1x = [derivative(f, xx, dx = 1e-6, n = 1) for xx in x]

# %%
# график функции и 1-ой производной
plt.plot(x, fx, label='function')
plt.plot(x, f1x, label='derivative')
plt.legend()
plt.show()

# %%
x = np.linspace(-5, 5)
fx = f(x)
f1x = [derivative(f, xx, dx = 1e-6, n = 2) for xx in x]

# %%
# график функции и 2-ой производной
plt.plot(x, fx, label='function')
plt.plot(x, f1x, label='derivative')
plt.legend()
plt.show()
