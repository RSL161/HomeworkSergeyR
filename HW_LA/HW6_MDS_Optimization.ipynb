# %% [markdown]
# ## Домашнее задание "Теория оптимизации".
# ### Задание.
# При фиксированном seed=42 поразбирайтесь и поэкспериментируйте с параметрами алгоритма дифференциальной эволюции: strategy, popsize, tol, mutation, recombination и updating.
#
# Постройте графики количества итераций оптимизации функции ackley от значения параметра.
#
# ### Дополнительное задание.
# Найти множество параметров (strategy=..., ..., updating=...), которые требуют минимального количества итераций.

# %% [markdown]
# scipy.optimize.differential_evolution(func, bounds, args=(), strategy='best1bin', maxiter=1000, popsize=15, tol=0.01, mutation=0.5, 1, recombination=0.7, seed=None, callback=None, disp=False, polish=True, init='latinhypercube', atol=0, updating='immediate', workers=1, constraints=())

# %%
import numpy as np
from scipy.optimize import differential_evolution
import matplotlib.pyplot as plt
from scipy.optimize import dual_annealing
from scipy.optimize import basinhopping

# %%
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]

# %%
result = differential_evolution(ackley, bounds, seed = 42)
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 2793
#      nit: 90
#  success: True
#        x: array([0., 0.])

# %% [markdown]
# * минимум:
# fun: 4.440892098500626e-16
#
# * сообщение причины прекращения
# message: 'Optimization terminated successfully.'
#
# * количество оценок функций:
# nfev: 2793
#
# * количество итераций,которые выполнил оптимизатор:
# nit: 90
#
# * решение удовлетворяет(или нет) применяемым ограничениям:
# success: True
#
# * точка достижения минимума
# x: array([0., 0.])

# %%
data = {'fun': result.fun, 'nfev': result.nfev, 'nit': result.nit}
names = list(data.keys())
values = list(data.values())

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True);
axs[0].bar(names, values);
axs[1].plot(names, values);
fig.suptitle('Графики количества итераций оптимизации функции ackley от значения параметра')
# Out:
# Text(0.5, 0.98, 'Графики количества итераций оптимизации функции ackley от значения параметра')

# %%
# добавляю параметры: strategy, popsize, tol, mutation, recombination и updating
# уменьшилось количество оценко и итераций
result = differential_evolution(ackley, bounds, strategy = 'best1bin', popsize = 10, tol = 0.01, mutation = 0.5, recombination = 0.7, seed = 42, updating='immediate')
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 1263
#      nit: 59
#  success: True
#        x: array([0., 0.])

# %%
data = {'fun': result.fun, 'nfev': result.nfev, 'nit': result.nit}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True);
axs[0].bar(names, values);
axs[1].plot(names, values);
fig.suptitle('Графики количества итераций оптимизации функции ackley от значения параметра')
# Out:
# Text(0.5, 0.98, 'Графики количества итераций оптимизации функции ackley от значения параметра')

# %%
# меняю strategy стратегию дифференциальной эволюции rand2bin 
# получаю максимальное к-во оценок и итераций
result = differential_evolution(ackley, bounds, strategy = 'rand2bin', popsize = 10, tol = 0.01, mutation = 0.5, recombination = 0.7, seed = 42, updating='immediate')
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 3483
#      nit: 170
#  success: True
#        x: array([0., 0.])

# %%
data = {'fun': result.fun, 'nfev': result.nfev, 'nit': result.nit}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True);
axs[0].bar(names, values);
axs[1].plot(names, values);
fig.suptitle('Графики количества итераций оптимизации функции ackley от значения параметра')
# Out:
# Text(0.5, 0.98, 'Графики количества итераций оптимизации функции ackley от значения параметра')

# %%
# меняю popsize множитель для определения общего размера 7
# к-во оценок стало меньше на 68% ,итераций уменьшилось на 17%
result = differential_evolution(ackley, bounds, strategy = 'rand2bin', popsize = 5, tol = 0.01, mutation = 0.5, recombination = 0.7, seed = 42, updating='immediate')
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 1493
#      nit: 142
#  success: True
#        x: array([0., 0.])

# %%
data = {'fun': result.fun, 'nfev': result.nfev, 'nit': result.nit}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True);
axs[0].bar(names, values);
axs[1].plot(names, values);
fig.suptitle('Графики количества итераций оптимизации функции ackley от значения параметра')
# Out:
# Text(0.5, 0.98, 'Графики количества итераций оптимизации функции ackley от значения параметра')

# %%
# меняю tol допуск на сходимость(прекращает решение при опр условиях)
# к-во оценок и итераций не изменились
result = differential_evolution(ackley, bounds, strategy = 'rand2bin', popsize = 5, tol = 0.11, mutation = 0.5, recombination = 0.7, seed = 42, updating='immediate')
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 1493
#      nit: 142
#  success: True
#        x: array([0., 0.])

# %%
data = {'fun': result.fun, 'nfev': result.nfev, 'nit': result.nit}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True);
axs[0].bar(names, values);
axs[1].plot(names, values);
fig.suptitle('Графики количества итераций оптимизации функции ackley от значения параметра')
# Out:
# Text(0.5, 0.98, 'Графики количества итераций оптимизации функции ackley от значения параметра')

# %%
# меняю mutation мутационная константа(от 0 до 2 или min - max) 
# с увеличением-увеличивается радиус поиска и замедляется сходимость 
# с увеличением от 0,5 к 1,5 :к-во оценок и итераций стало больше в 4 раза
result = differential_evolution(ackley, bounds, strategy = 'rand2bin', popsize = 5, tol = 0.01, mutation = 1.5, recombination = 0.7, seed = 42, updating='immediate')
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 6003
#      nit: 593
#  success: True
#        x: array([0., 0.])

# %%
data = {'fun': result.fun, 'nfev': result.nfev, 'nit': result.nit}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True);
axs[0].bar(names, values);
axs[1].plot(names, values);
fig.suptitle('Графики количества итераций оптимизации функции ackley от значения параметра')
# Out:
# Text(0.5, 0.98, 'Графики количества итераций оптимизации функции ackley от значения параметра')

# %%
# меняю recombination константа рекомбинации(от 0 до 1) 
# с увеличением- снижает стабильность следующей популяции за счет большего перехода мутирующих векторов
# с увеличением с 0,7 до 0,9 :к-во оценок и итераций увеличилось на 10%
result = differential_evolution(ackley, bounds, strategy = 'rand2bin', popsize = 5, tol = 0.01, mutation = 1.5, recombination = 0.9, seed = 42, updating='immediate')
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 6823
#      nit: 675
#  success: True
#        x: array([0., 0.])

# %%
data = {'fun': result.fun, 'nfev': result.nfev, 'nit': result.nit}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True);
axs[0].bar(names, values);
axs[1].plot(names, values);
fig.suptitle('Графики количества итераций оптимизации функции ackley от значения параметра')
# Out:
# Text(0.5, 0.98, 'Графики количества итераций оптимизации функции ackley от значения параметра')

# %%
# меняю updating два значения- ‘immediate’ , ‘deferred’} 
# immediate - постоянно обновляется в перделах одного поколения - ведет к более быстрой сходимости
# deferred - один раз  обновляется в перделах одного поколения
# к-во оценок и итераций увеличилось не значительно
result = differential_evolution(ackley, bounds, strategy = 'rand2bin', popsize = 5, tol = 0.01, mutation = 1.5, recombination = 0.9, seed = 42, updating ='deferred')
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 7193
#      nit: 712
#  success: True
#        x: array([0., 0.])

# %%
data = {'fun': result.fun, 'nfev': result.nfev, 'nit': result.nit}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True);
axs[0].bar(names, values);
axs[1].plot(names, values);
fig.suptitle('Графики количества итераций оптимизации функции ackley от значения параметра')
# Out:
# Text(0.5, 0.98, 'Графики количества итераций оптимизации функции ackley от значения параметра')

# %% [markdown]
# ##### Дополнительное задание.
# Найти множество параметров (strategy=..., ..., updating=...), которые требуют минимального количества итераций.

# %% [markdown]
# * Выбрал ручной путь решения

# %%
# меняю strategy стратегию дифференциальной эволюции best1bin 
# меняю popsize на 1
# меняю tol - не влияет на к-во итераций
# меняю mutation на минимальный 0,1
# меняю recombination на максимальный 0,99
# меняю updating два значения- ‘immediate’ , ‘deferred’} 
# получаю миниамльное к-во итераций - 2
# точка минимума сместилась
result = differential_evolution(ackley, bounds, strategy = 'best1bin', popsize = 1, tol = 0.01, mutation = 0.1, recombination = 0.99, seed = 42, updating='immediate')
result
# Out:
#      fun: 5.381864187490667
#      jac: array([3.55271366e-06, 5.32907055e-06])
#  message: 'Optimization terminated successfully.'
#     nfev: 51
#      nit: 2
#  success: True
#        x: array([-0.98241596, -1.96461655])

# %%
result.nit
# Out:
# 2

# %%
data = {'fun': result.fun, 'nfev': result.nfev, 'nit': result.nit}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True);
axs[0].bar(names, values);
axs[1].plot(names, values);
fig.suptitle('Графики количества итераций оптимизации функции ackley от значения параметра')
# Out:
# Text(0.5, 0.98, 'Графики количества итераций оптимизации функции ackley от значения параметра')
