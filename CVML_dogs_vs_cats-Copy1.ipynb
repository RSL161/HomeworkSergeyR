# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import vgg16

print(tf.__version__)
print(tf.executing_eagerly())
# Out:
# 2.4.0
# True

# %% [markdown]
# ## Функции загрузки данных

# %%
import os
from random import shuffle
from glob import glob

IMG_SIZE = (224, 224)  # размер входного изображения сети

train_files = glob('data/train/*.jpg')
test_files = glob('data/test/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=64):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)

# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %%
train_files[0]
# Out:
# 'data/train\\cat.0.jpg'

# %%
test_files[0]
# Out:
# 'data/test\\1.jpg'

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img);

# %%
# base_model - объект класса keras.models.Model (Functional Model)
base_model = vgg16.VGG16(weights='imagenet',
                         include_top = False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Добавляем полносвязный слой

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False


x = base_model.layers[-5].output

x = tf.keras.layers.Flatten()(x)

# x = tf.keras.layers.Dropout(0.5)(x)

x = tf.keras.layers.BatchNormalization(axis = -1)(x)


x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation = 'sigmoid',  # функция активации  
                          kernel_regularizer = tf.keras.regularizers.l1(1e-4))(x)

# x = tf.keras.layers.Dropout(0.1)(x)

# %%
model = tf.keras.Model(inputs = base_model.input, outputs = x, name = 'dogs_vs_cats')

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100352)            401408
# _________________________________________________________________
# dense (Dense)                (None, 1)                 100353
# =================================================================
# Total params: 8,137,025
# Trainable params: 301,057
# Non-trainable params: 7,835,968
# _________________________________________________________________

# %%
# chek count params
14*14*512+1
# Out:
# 100353

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy'])

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
                              monitor='val_loss',
                              patience=5,
                              min_delta=1e-7,
                              verbose=2,
                              factor=.5,
                              min_lr=1e-10,
                              mode='auto')

early_stopping = tf.keras.callbacks.EarlyStopping(
                              monitor='val_loss',
                              min_delta=1e-7,
                              patience=5,
                              verbose=2,
                              mode='auto',
                              restore_best_weights=False)

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                              'model_VGG16_custom.h5',
                              monitor='val_loss',
                              verbose=1, 
                              save_best_only=True, 
                              save_weights_only=True,
                              mode='min')

# %%
shuffle(train_files)
validation_data = next(fit_generator(train_files))
train_data = fit_generator(train_files)

# %%
hist = model.fit(train_data,
                 batch_size = 64,
                 steps_per_epoch = 100,
                 epochs = 100,
                 validation_data = validation_data,
                 callbacks = [model_checkpoint, reduce_lr, early_stopping])
# Out:
# Epoch 1/100
# 100/100 [==============================] - 634s 6s/step - loss: 0.6255 - accuracy: 0.8411 - val_loss: 0.6214 - val_accuracy: 0.9219
#
# Epoch 00001: val_loss improved from inf to 0.62140, saving model to model_VGG16_custom.h5
# Epoch 2/100
# 100/100 [==============================] - 633s 6s/step - loss: 0.5637 - accuracy: 0.9113 - val_loss: 0.3831 - val_accuracy: 0.9531
#
# Epoch 00002: val_loss improved from 0.62140 to 0.38306, saving model to model_VGG16_custom.h5
# Epoch 3/100
# 100/100 [==============================] - 637s 6s/step - loss: 0.5748 - accuracy: 0.9205 - val_loss: 0.3142 - val_accuracy: 0.9688
#
# Epoch 00003: val_loss improved from 0.38306 to 0.31417, saving model to model_VGG16_custom.h5
# Epoch 4/100
# 100/100 [==============================] - 638s 6s/step - loss: 0.6132 - accuracy: 0.9280 - val_loss: 0.1396 - val_accuracy: 1.0000
#
# Epoch 00004: val_loss improved from 0.31417 to 0.13963, saving model to model_VGG16_custom.h5
# Epoch 5/100
# 100/100 [==============================] - 633s 6s/step - loss: 0.2663 - accuracy: 0.9685 - val_loss: 0.1627 - val_accuracy: 0.9688
#
# Epoch 00005: val_loss did not improve from 0.13963
# Epoch 6/100
# 100/100 [==============================] - 630s 6s/step - loss: 0.3111 - accuracy: 0.9692 - val_loss: 0.1563 - val_accuracy: 0.9844
#
# Epoch 00006: val_loss did not improve from 0.13963
# Epoch 7/100
# 100/100 [==============================] - 643s 6s/step - loss: 0.3750 - accuracy: 0.9647 - val_loss: 0.1481 - val_accuracy: 1.0000
#
# Epoch 00007: val_loss did not improve from 0.13963
# Epoch 8/100
# 100/100 [==============================] - 637s 6s/step - loss: 0.3283 - accuracy: 0.9693 - val_loss: 0.3001 - val_accuracy: 0.9531
#
# Epoch 00008: val_loss did not improve from 0.13963
# Epoch 9/100
# 100/100 [==============================] - 629s 6s/step - loss: 0.2582 - accuracy: 0.9798 - val_loss: 0.2799 - val_accuracy: 0.9531
#
# Epoch 00009: val_loss did not improve from 0.13963
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 00009: early stopping

# %%
model.save('20210914_cats-dogs-vgg16.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
test_pred = model.predict(
    predict_generator(test_files), steps=len(test_files))

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:10], test_pred[:10]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %% [markdown]
# ## Готовим данные для отправки

# %%
import re

with open('submit_cats_dogs_7.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, test_pred):
        dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:14], test_pred[:14]),1):
    subplot = fig.add_subplot(2, 7, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %%
test_pred
# Out:
# array([[1.0000000e+00],
#        [6.2672600e-10],
#        [9.9172714e-10],
#        ...,
#        [1.0000000e+00],
#        [8.6981874e-26],
#        [7.6388191e-19]], dtype=float32)

# %%
# LogLoss = 0.65259

# %%
from IPython.display import Image

# %%
Image("2021_09_14_21_37_19_Dogs_vs._Cats_Redux_Kernels_Edition_Kaggle.jpg")
